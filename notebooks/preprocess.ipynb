# %% [markdown]
# #### Load Data

# %%
# Load JSON data into a dataframe
import pandas as pd
import json


def load_data():
    with open(r'..\data\scrape_results\dashen\review_dashen_bank_scrape_result.json', 'r', encoding='utf-8') as dashed_data:
        dashen_json = json.load(dashed_data)
        df_dashen = pd.DataFrame(dashen_json)
    with open(r'..\data\scrape_results\boa\review_boa_bank_scrape_result.json', 'r', encoding='utf-8') as boa_data:
        boa_json = json.load(boa_data)
        df_boa = pd.DataFrame(boa_json)
    with open(r'..\data\scrape_results\cbe\review_cbe_bank_scrape_result.json', 'r', encoding='utf-8') as cbe_data:
        cbe_json = json.load(cbe_data)
        df_cbe = pd.DataFrame(cbe_json)
    return df_dashen, df_boa, df_cbe

df_dashen, df_boa, df_cbe = load_data()

# %%
df_dashen.head()
# Out:
#                                reviewId              userName  \
# 0  22818807-3368-446c-8a3b-d3ca2e07a2d8               OBSA KA
# 1  6ece1f5e-55f2-404d-b980-1cb45823180f              Masersha
# 2  765ff69f-5274-45c5-985b-81b8d01e1874         Koki Mulugeta
# 3  7db66b6a-a044-43f1-a7ad-ea8a10815548    Badhasa Dassaalany
# 4  caf4a80c-85db-4b49-ab9c-a0b55e152317  Nebiyu Getachew Mamo
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                content  score  thumbsUpCount  \
# 0                                 love      3              0
# 1                                 መቸሸጠ      5              0
# 2                                  wow      5              0
# ...

# %%
df_boa.head()
# Out:
#                                reviewId           userName  \
# 0  937102c6-ae88-419c-994b-80e520faacb8    Phillmon Haftom
# 1  3559b91c-fad9-4032-bebe-cf99974b9628    Robel Alebachew
# 2  10e85f30-540d-4810-ba89-85a7e004480b  Haymanot Anberber
# 3  d7f07898-4ba1-47b4-9e8c-a3cc10b1bf0f  Mohamed Abdillahi
# 4  2ca9480b-ff5f-4b59-952c-5921db83dab2         Ahadu tech
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                                   it's not working      3              0
# 1  Hello, I’m facing a problem with the BOA Mobil...      1              0
# ...

# %%
df_cbe.head()
# Out:
#                                reviewId        userName  \
# 0  be2cb2ac-bbe0-4175-81c4-9f6c86afdaaa     Aim4 Beyond
# 1  8efd71e9-59cd-41ce-8c5c-12052dee9ad0       zakir man
# 2  b12d0383-9b27-4e49-a94d-277a43b15800     Yesuf Ahmed
# 3  dd9f9e37-177a-46df-b877-d0edaa9aed29  Yonas Mekonnen
# 4  8e34703c-203c-4180-8b32-bfd0b3f0c871     Yibrah Yebo
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  "Why don’t your ATMs support account-to-accoun...      4              0
# 1                        what is this app problem???      1              0
# 2       the app is proactive and a good connections.      5              0
# ...

# %%
def get_info():
    print("------------------------------------")
    print("CBE BANK INFO")
    df_cbe.info()
    print("------------------------------------")
    print("BOA BANK INFO")
    df_boa.info()
    print("------------------------------------")
    print("DASHEN BANK INFO")
    df_dashen.info()

get_info()
# Out:
# ------------------------------------
# CBE BANK INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7498 entries, 0 to 7497
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              7498 non-null   object
#  1   userName              7498 non-null   object
#  2   userImage             7498 non-null   object
#  3   content               7491 non-null   object
#  4   score                 7498 non-null   int64
#  5   thumbsUpCount         7498 non-null   int64
#  6   reviewCreatedVersion  6152 non-null   object
#  7   at                    7498 non-null   object
#  8   replyContent          47 non-null     object
#  9   repliedAt             47 non-null     object
#  10  appVersion            6152 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 644.5+ KB
# ------------------------------------
# BOA BANK INFO
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
def null_percentage(df):
    number_of_rows, number_of_columns = df.shape
    df_size = number_of_rows * number_of_columns
    
    null_size = (df.isnull().sum()).sum()
    percentage = round((null_size / df_size) * 100, 2)
    return f"Data Frame contain total null values of { percentage }%"

def calculate_total_null_values():
    print("------------------------------------")
    print("CBE BANK NULL VALUES")
    result = null_percentage(df_cbe)
    print(f"CBE dataframe: {result}")
    print("------------------------------------")
    print("BOA BANK NULL VALUES")
    result = null_percentage(df_boa)
    print(f"BOA dataframe: {result}")
    print("------------------------------------")
    print("DASHEN BANK NULL VALUES")
    result = null_percentage(df_dashen)
    print(f"DASHEN dataframe: {result}")
calculate_total_null_values()
# Out:
# ------------------------------------
# CBE BANK NULL VALUES
# CBE dataframe: Data Frame contain total null values of 21.34%
# ------------------------------------
# BOA BANK NULL VALUES
# BOA dataframe: Data Frame contain total null values of 22.84%
# ------------------------------------
# DASHEN BANK NULL VALUES
# DASHEN dataframe: Data Frame contain total null values of 21.88%

# %%
def missing_values_per_column(df):
    return df.isnull().sum()

def calculate_missing_values_per_column():
    print("------------------------------------")
    print("CBE BANK COLUMN MISSING VALUES")
    result = missing_values_per_column(df_cbe)
    print(f"CBE dataframe: {result}")
    print("------------------------------------")
    print("BOA BANK COLUMN MISSING VALUES")
    result = missing_values_per_column(df_boa)
    print(f"BOA dataframe: {result}")
    print("------------------------------------")
    print("DASHEN BANK COLUMN MISSING VALUES")
    result = missing_values_per_column(df_dashen)
    print(f"DASHEN dataframe: {result}")

calculate_missing_values_per_column()
# Out:
# ------------------------------------
# CBE BANK COLUMN MISSING VALUES
# CBE dataframe: reviewId                   0
# userName                   0
# userImage                  0
# content                    7
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    1346
# at                         0
# replyContent            7451
# repliedAt               7451
# appVersion              1346
# dtype: int64
# ------------------------------------
# BOA BANK COLUMN MISSING VALUES
# BOA dataframe: reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion     291
# at                         0
# replyContent            1022
# repliedAt               1022
# appVersion               291
# dtype: int64
# ------------------------------------
# DASHEN BANK COLUMN MISSING VALUES
# ...

# %% [markdown]
# As can be seen from the above output, most missing values are concentrated on columns
# replyContent
# repliedAt
# appVersion
#
# Hence we will remove these columns and recalculate the missing values percentage and check
# if its less than 5%

# %% [markdown]
# #### Dropping columns with high numer of missing values

# %%
df_cbe = df_cbe.drop(['replyContent', 'repliedAt', 'appVersion'], axis=1)
df_boa = df_boa.drop(['replyContent', 'repliedAt', 'appVersion'], axis=1)
df_dashen = df_dashen.drop(['replyContent', 'repliedAt', 'appVersion'], axis=1)

# %% [markdown]
# #### Re-calculating total null values

# %%
calculate_total_null_values()
# Out:
# ------------------------------------
# CBE BANK NULL VALUES
# CBE dataframe: Data Frame contain total null values of 2.26%
# ------------------------------------
# BOA BANK NULL VALUES
# BOA dataframe: Data Frame contain total null values of 3.48%
# ------------------------------------
# DASHEN BANK NULL VALUES
# DASHEN dataframe: Data Frame contain total null values of 2.54%

# %% [markdown]
# #### Check for duplicates

# %%
def check_for_duplicates(df):
    duplicates_df = df[df.duplicated()]
    return duplicates_df

def check_duplicates_for_all_banks():
    print("------------------------------------")
    print("CBE BANK DUPLICATES")
    result = check_for_duplicates(df_cbe)
    print(f"CBE duplicates dataframe: {result}")
    print("------------------------------------")
    print("BOA BANK DUPLICATES")
    result = check_for_duplicates(df_boa)
    print(f"BOA duplicates dataframe: {result}")
    print("------------------------------------")
    print("DASHEN BANK DUPLICATES")
    result = check_for_duplicates(df_dashen)
    print(f"DASHEN duplicates dataframe: {result}")

check_duplicates_for_all_banks()
# Out:
# ------------------------------------
# CBE BANK DUPLICATES
# CBE duplicates dataframe: Empty DataFrame
# Columns: [reviewId, userName, userImage, content, score, thumbsUpCount, reviewCreatedVersion, at]
# Index: []
# ------------------------------------
# BOA BANK DUPLICATES
# BOA duplicates dataframe: Empty DataFrame
# Columns: [reviewId, userName, userImage, content, score, thumbsUpCount, reviewCreatedVersion, at]
# Index: []
# ------------------------------------
# DASHEN BANK DUPLICATES
# DASHEN duplicates dataframe: Empty DataFrame
# Columns: [reviewId, userName, userImage, content, score, thumbsUpCount, reviewCreatedVersion, at]
# Index: []

# %%
def normalize_date(df):
    # Convert 'at' column to datetime object
    df['at'] = pd.to_datetime(df['at'], errors='coerce')
    df['date'] = df['at'].dt.normalize()

def normalize_dates_for_all_banks():
    normalize_date(df_cbe)
    normalize_date(df_boa)
    normalize_date(df_dashen)

normalize_dates_for_all_banks()

# %%
print("------------------------------------")
print("CBE BANK")
df_cbe.head()
# Out:
# ------------------------------------
# CBE BANK
#                                reviewId        userName  \
# 0  be2cb2ac-bbe0-4175-81c4-9f6c86afdaaa     Aim4 Beyond
# 1  8efd71e9-59cd-41ce-8c5c-12052dee9ad0       zakir man
# 2  b12d0383-9b27-4e49-a94d-277a43b15800     Yesuf Ahmed
# 3  dd9f9e37-177a-46df-b877-d0edaa9aed29  Yonas Mekonnen
# 4  8e34703c-203c-4180-8b32-bfd0b3f0c871     Yibrah Yebo
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  "Why don’t your ATMs support account-to-accoun...      4              0
# 1                        what is this app problem???      1              0
# ...

# %%
print("------------------------------------")
print("BOA BANK")
df_boa.head()
# Out:
# ------------------------------------
# BOA BANK
#                                reviewId           userName  \
# 0  937102c6-ae88-419c-994b-80e520faacb8    Phillmon Haftom
# 1  3559b91c-fad9-4032-bebe-cf99974b9628    Robel Alebachew
# 2  10e85f30-540d-4810-ba89-85a7e004480b  Haymanot Anberber
# 3  d7f07898-4ba1-47b4-9e8c-a3cc10b1bf0f  Mohamed Abdillahi
# 4  2ca9480b-ff5f-4b59-952c-5921db83dab2         Ahadu tech
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                                   it's not working      3              0
# 1  Hello, I’m facing a problem with the BOA Mobil...      1              0
# ...

# %%
print("------------------------------------")
print("DASHEN BANK")
df_dashen.head()
# Out:
# ------------------------------------
# DASHEN BANK
#                                reviewId              userName  \
# 0  22818807-3368-446c-8a3b-d3ca2e07a2d8               OBSA KA
# 1  6ece1f5e-55f2-404d-b980-1cb45823180f              Masersha
# 2  765ff69f-5274-45c5-985b-81b8d01e1874         Koki Mulugeta
# 3  7db66b6a-a044-43f1-a7ad-ea8a10815548    Badhasa Dassaalany
# 4  caf4a80c-85db-4b49-ab9c-a0b55e152317  Nebiyu Getachew Mamo
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                content  score  thumbsUpCount  \
# 0                                 love      3              0
# 1                                 መቸሸጠ      5              0
# ...

# %%
def add_bank_source_rating_review(df, bank, source):
    df['review'] = df['content']
    df['bank'] = bank
    df['source'] = source
    df['rating'] = df['score']

def add_bank_source_review_rating_for_all_banks():
    print("------------------------------------")
    print("CBE BANK")
    add_bank_source_rating_review(df_cbe, 'cbe', 'playstore')
    df_cbe.info()
    print("------------------------------------")
    print("BOA BANK")
    add_bank_source_rating_review(df_boa, 'boa', 'playstore')
    df_boa.info()
    print("------------------------------------")
    print("DASHEN BANK")   
    add_bank_source_rating_review(df_dashen, 'dashen', 'playstore')
    df_dashen.info()

add_bank_source_review_rating_for_all_banks()
# Out:
# ------------------------------------
# CBE BANK
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 21
#      18     add_bank_source_rating_review(df_dashen, 'dashen', 'playstore')
#      19     df_dashen.info()
# ---> 21 add_bank_source_review_rating_for_all_banks()
#
# Cell In[110], line 10, in add_bank_source_review_rating_for_all_banks()
#       8 print("------------------------------------")
#       9 print("CBE BANK")
# ---> 10 add_bank_source_rating_review(df_cbe, 'cbe', 'playstore')
#      11 df_cbe.info()
#      12 print("------------------------------------")
#
# Cell In[110], line 4, in add_bank_source_rating_review(df, bank, source)
#       2 df['review'] = df['content']
#       3 df['bank'] = bank
# ----> 4 df['source'] = source,
#       5 df['rating'] = df['score']
#
# ...

# %%
print("CBE BANK")
df_cbe.head(1)
# Out:
# CBE BANK
#                                reviewId     userName  \
# 0  be2cb2ac-bbe0-4175-81c4-9f6c86afdaaa  Aim4 Beyond
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  "Why don’t your ATMs support account-to-accoun...      4              0
#
#   reviewCreatedVersion                  at       date  \
# 0                 None 2025-06-06 09:54:11 2025-06-06
#
#                                               review bank     source
# 0  "Why don’t your ATMs support account-to-accoun...  cbe  playstore

# %%
print("BOA BANK")
df_boa.head(1)
# Out:
# BOA BANK
#                                reviewId         userName  \
# 0  937102c6-ae88-419c-994b-80e520faacb8  Phillmon Haftom
#
#                                            userImage           content  score  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...  it's not working      3
#
#    thumbsUpCount reviewCreatedVersion                  at       date  \
# 0              0             25.05.03 2025-06-05 11:57:36 2025-06-05
#
#              review bank     source
# 0  it's not working  boa  playstore

# %%
print("DASHEN BANK")
df_dashen.head(1)
# Out:
# DASHEN BANK
#                                reviewId userName  \
# 0  22818807-3368-446c-8a3b-d3ca2e07a2d8  OBSA KA
#
#                                            userImage content  score  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...    love      3
#
#    thumbsUpCount reviewCreatedVersion                  at       date review  \
# 0              0               1.0.16 2025-06-06 00:15:44 2025-06-06   love
#
#      bank     source
# 0  dashen  playstore

# %% [markdown]
# #### Save to CSV

# %%
df_cbe.to_csv(r'..\data\scrape_cleaned\cbe_cleaned.csv', columns=['review', 'rating', 'date', 'bank', 'source'], index=False)
df_boa.to_csv(r'..\data\scrape_cleaned\boa_cleaned.csv', columns=['review', 'rating', 'date', 'bank', 'source'], index=False)
df_dashen.to_csv(r'..\data\scrape_cleaned\dashen_cleaned.csv', columns=['review', 'rating', 'date', 'bank', 'source'], index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 df_cbe.to_csv(r'..\data\scrape_cleaned\cbe_cleaned.csv', columns=['review', 'rating', 'date', 'bank', 'source'], index=False)
#       2 df_boa.to_csv(r'..\data\scrape_cleaned\boa_cleaned.csv', columns=['review', 'rating', 'date', 'bank', 'source'], index=False)
#       3 df_dashen.to_csv(r'..\data\scrape_cleaned\dashen_cleaned.csv', columns=['review', 'rating', 'date', 'bank', 'source'], index=False)
#
# File c:\Users\redie\.pyenv\pyenv-win\versions\3.10.0\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
# ...
